# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd

# %%
# urlbase_2019 = 'https://api.competitor.com/public/result/subevent/622BBEE3-D94F-E811-941E-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip='
# urlbase_2018 = 'https://api.competitor.com/public/result/subevent/DEDEEE82-E676-E711-9418-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip='
# urlbase_2017 = 'https://api.competitor.com/public/result/subevent/9D1CE788-E676-E711-9418-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip='
# headers = {'WTC_PRIV_KEY': '90da38d91a0648f89823e375a43b2dc8'}

# %%
url = 'https://api.competitor.com/public/result/subevent/622BBEE3-D94F-E811-941E-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip='# + str((page_num-1)*50)

# %%
response = requests.get(url, headers = {'WTC_PRIV_KEY': '90da38d91a0648f89823e375a43b2dc8'})

# %%
response.url
# Out:
# 'https://api.competitor.com/public/result/subevent/622BBEE3-D94F-E811-941E-005056951BF1?$limit=50&$sort%5BFinishRankOverall%5D=1&$skip='

# %%
data = response.json()

# %%
data
# Out:
# {'total': 2811,
#  'limit': 50,
#  'skip': 0,
#  'data': [{'RunTimeConverted': '1:37:54',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '1:37:54',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'BAD64F55-2468-4852-B2D7-79645CC406CF',
#    'ContactId': 'EB221D69-153D-4604-96E0-274EB04F452C',
#    'AgeGroup': 'PC',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30001,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 5874,
#    'FinishTime': 5874,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 1,
#    'FinishRankOverall': 1,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 1,
#    'RunRankOverall': 1,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Travis Peruski', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:34:59',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:34:59',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'BA893A3C-B2BB-4C83-B372-AF68521F7FB6',
#    'ContactId': 'BED376E7-A066-43C9-A759-4C476A939CFA',
#    'AgeGroup': 'MElite',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 1,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 9299,
#    'FinishTime': 9299,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 2,
#    'FinishRankOverall': 2,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 2,
#    'RunRankOverall': 2,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Scott Wietecha', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:35:24',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:35:24',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'B67E182D-62C5-493F-BEE8-83363643BE44',
#    'ContactId': '936B5582-6102-42FC-8F8A-559D44484658',
#    'AgeGroup': 'MElite',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 4,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 9324,
#    'FinishTime': 9324,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 3,
#    'FinishRankOverall': 3,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 3,
#    'RunRankOverall': 3,
#    'SyncDate': '2020-03-17T16:30:36.613Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Jordan Wilson', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:39:59',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:39:59',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'FF8F0161-90E0-4298-A45C-87AD948F1D44',
#    'ContactId': 'EB229CF3-2728-42AD-BC06-5947D5E37E02',
#    'AgeGroup': 'M30-34',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30034,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 9599,
#    'FinishTime': 9599,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 4,
#    'FinishRankOverall': 4,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 4,
#    'RunRankOverall': 4,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Steelton Flynn', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:42:09',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:42:09',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '7FC27297-AF8E-40ED-843E-69BB6FEC2E9D',
#    'ContactId': 'F4146BE6-9A35-45B4-8EB2-8063C207DEBC',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30035,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 9729,
#    'FinishTime': 9729,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 5,
#    'FinishRankOverall': 5,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 5,
#    'RunRankOverall': 5,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Thomas Ellis', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:48:42',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:48:42',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'A6C08FB3-548E-4DCE-A76C-1957AB0C28C2',
#    'ContactId': 'F22F5953-8AA4-4410-8A55-CFD9D68B9994',
#    'AgeGroup': 'M30-34',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 33172,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10122,
#    'FinishTime': 10122,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 6,
#    'FinishRankOverall': 6,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 6,
#    'RunRankOverall': 6,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Nicholas Tseffos', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:50:33',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:50:33',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '32C7432B-EA04-4DA1-BAC0-38FBEC923307',
#    'ContactId': 'B3F1B1B0-E630-4E70-B3B2-B81B1B8B003A',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30053,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10233,
#    'FinishTime': 10233,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 7,
#    'FinishRankOverall': 7,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 7,
#    'RunRankOverall': 7,
#    'SyncDate': '2021-01-29T17:30:24.043Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Satoshi Mitsumori', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:51:18',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:51:18',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'F790AB8F-475F-41AE-91C9-AD0E2D522507',
#    'ContactId': 'DC264BD9-85CC-420D-91C5-13D90C68CA72',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30051,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10278,
#    'FinishTime': 10278,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 8,
#    'FinishRankOverall': 8,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 8,
#    'RunRankOverall': 8,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Harrison Kieffer', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:54:34',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:54:34',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '2E60BCBE-7229-4612-9689-8AF74200A571',
#    'ContactId': '4885DB41-372D-44A2-ADEC-42B9F2A09924',
#    'AgeGroup': 'M18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30086,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10474,
#    'FinishTime': 10474,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 9,
#    'FinishRankOverall': 9,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 9,
#    'RunRankOverall': 9,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Steven Forte', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:55:49',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:55:49',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '3AA3F39D-B66B-4C2B-8CBB-3B117BD1DE23',
#    'ContactId': 'C94B684B-20ED-479D-AB52-DAB8D37B7CE7',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30042,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10549,
#    'FinishTime': 10549,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 10,
#    'FinishRankOverall': 10,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 10,
#    'RunRankOverall': 10,
#    'SyncDate': '2020-12-06T10:10:41.187Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Grant Rice', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:56:05',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:56:05',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'A462653F-74AF-45E4-BD4E-309617CC061C',
#    'ContactId': 'AB201DD0-A3A9-4A81-A3FF-2161EAAE6B3A',
#    'AgeGroup': 'M40-44',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30049,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10565,
#    'FinishTime': 10565,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 11,
#    'FinishRankOverall': 11,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 11,
#    'RunRankOverall': 11,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Andrew Fisher', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:56:40',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:56:40',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'B94A10EE-B5C8-4394-A7A6-7A3CBB3F90BB',
#    'ContactId': 'A8F56DFF-89D4-4DFD-A7EB-318BC0D4D32A',
#    'AgeGroup': 'M40-44',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30038,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10600,
#    'FinishTime': 10600,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 12,
#    'FinishRankOverall': 12,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 12,
#    'RunRankOverall': 12,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Edgar Garza', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:56:58',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:56:58',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '43BCC37F-2B13-4C5F-BDF9-0D43FBBE1758',
#    'ContactId': 'AAFBBF9B-0D2E-4154-8F20-0F62E72E0FD9',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30094,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10618,
#    'FinishTime': 10618,
#    'FinishRankGroup': 3,
#    'FinishRankGender': 13,
#    'FinishRankOverall': 13,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 3,
#    'RunRankGender': 13,
#    'RunRankOverall': 13,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Wesley King', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:57:38',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:57:38',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '3B032EF5-C7A7-41AB-9E52-2A5133F5CA52',
#    'ContactId': '99BB5CCB-319B-4395-8D7C-2BE029A9D7AD',
#    'AgeGroup': 'M18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30112,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10658,
#    'FinishTime': 10658,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 14,
#    'FinishRankOverall': 14,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 14,
#    'RunRankOverall': 14,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Jake Smith', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:58:00',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:58:00',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'CE995825-EE98-4677-BE59-12113860999A',
#    'ContactId': '6E26060E-4AB3-404D-8D2B-E84202C60503',
#    'AgeGroup': 'M45-49',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30096,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10680,
#    'FinishTime': 10680,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 15,
#    'FinishRankOverall': 15,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 15,
#    'RunRankOverall': 15,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Mark Laprade', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:59:09',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:59:09',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '1CC1EEC8-EA31-46BC-996F-AFBD8F0D8655',
#    'ContactId': '54C6EEBD-0A97-430B-B4F6-99BC5D1E4B06',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30142,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10749,
#    'FinishTime': 10749,
#    'FinishRankGroup': 4,
#    'FinishRankGender': 16,
#    'FinishRankOverall': 16,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 4,
#    'RunRankGender': 16,
#    'RunRankOverall': 16,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Scott Roman', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '2:59:59',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '2:59:59',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '2DC07A0C-6217-4AF8-8345-132AC05BB077',
#    'ContactId': '8BF483D7-E634-42F4-8043-0819319F49D9',
#    'AgeGroup': 'M50-54',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30054,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10799,
#    'FinishTime': 10799,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 17,
#    'FinishRankOverall': 17,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 17,
#    'RunRankOverall': 17,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'James Nabholz', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:01:21',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:01:21',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '4CFE6693-C19B-4A9A-A0FB-DB3110B8DC63',
#    'ContactId': '34B5DAE2-0F25-46B0-86A3-71C56E5C496D',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30056,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10881,
#    'FinishTime': 10881,
#    'FinishRankGroup': 3,
#    'FinishRankGender': 18,
#    'FinishRankOverall': 18,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 3,
#    'RunRankGender': 18,
#    'RunRankOverall': 18,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Kazufumi Seki', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:01:59',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:01:59',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'BBD3BC14-30C0-4EDD-B951-4765C6EDA97F',
#    'ContactId': '9130D1F0-E33C-4A89-824E-90C43F836BD4',
#    'AgeGroup': 'M30-34',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30084,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10919,
#    'FinishTime': 10919,
#    'FinishRankGroup': 3,
#    'FinishRankGender': 19,
#    'FinishRankOverall': 19,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 3,
#    'RunRankGender': 19,
#    'RunRankOverall': 19,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Nicholas Eulau', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:02:18',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:02:18',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '5F54FA9D-5F51-4151-AA64-A1964B0DD40E',
#    'ContactId': '2FA32A23-EAC5-479F-81D5-BE7634CC3E57',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30045,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10938,
#    'FinishTime': 10938,
#    'FinishRankGroup': 5,
#    'FinishRankGender': 20,
#    'FinishRankOverall': 20,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 5,
#    'RunRankGender': 20,
#    'RunRankOverall': 20,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Mitchell Davis', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:03:12',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:03:12',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'ADE6E23A-8F89-4F44-9481-DD66EFD4AB3C',
#    'ContactId': 'FBC87FE2-91DD-48E9-A11C-E2CBBDFC8593',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30075,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10992,
#    'FinishTime': 10992,
#    'FinishRankGroup': 4,
#    'FinishRankGender': 21,
#    'FinishRankOverall': 21,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 4,
#    'RunRankGender': 21,
#    'RunRankOverall': 21,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Eddie Bell', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:03:17',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:03:17',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'D4D9A477-C34F-4E3B-AAAF-1FDD84D6DB80',
#    'ContactId': 'FE71F855-9A18-4A05-81BF-D4B29136D024',
#    'AgeGroup': 'M18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30039,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 10997,
#    'FinishTime': 10997,
#    'FinishRankGroup': 3,
#    'FinishRankGender': 22,
#    'FinishRankOverall': 22,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 3,
#    'RunRankGender': 22,
#    'RunRankOverall': 22,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Montana Klingsporn', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:04:01',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:04:01',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'SE',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'D6A6E679-E636-4359-B94A-E0F6CC915170',
#    'ContactId': 'D69032B9-A7E8-4915-8749-7F2AABB8831B',
#    'AgeGroup': 'MElite',
#    'CountryRepresentingISONumeric': 752,
#    'BibNumber': 2,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11041,
#    'FinishTime': 11041,
#    'FinishRankGroup': 3,
#    'FinishRankGender': 23,
#    'FinishRankOverall': 23,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 3,
#    'RunRankGender': 23,
#    'RunRankOverall': 23,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Mathias Osmark', 'Gender': 'M'},
#    'Country': {'ISO2': 'SE'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:05:22',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:05:22',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'B7605D97-EEA9-4CDB-899A-0179D4563D6E',
#    'ContactId': 'A346BCE2-98E5-4F06-8232-A92EEDF20F9F',
#    'AgeGroup': 'M30-34',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30052,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11122,
#    'FinishTime': 11122,
#    'FinishRankGroup': 4,
#    'FinishRankGender': 24,
#    'FinishRankOverall': 24,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 4,
#    'RunRankGender': 24,
#    'RunRankOverall': 24,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Sean Kunis', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:05:28',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:05:28',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '79410326-4FE6-435F-8DD5-615C810F7064',
#    'ContactId': '5F0FD993-03AB-460B-B645-6B8B9FB5531D',
#    'AgeGroup': 'M18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30074,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11128,
#    'FinishTime': 11128,
#    'FinishRankGroup': 4,
#    'FinishRankGender': 25,
#    'FinishRankOverall': 25,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 4,
#    'RunRankGender': 25,
#    'RunRankOverall': 25,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Dylan Beaulieu', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:06:05',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:06:05',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'VE',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'BA67DCC9-F4F7-4069-9FDB-3B28667E578F',
#    'ContactId': '9360C587-1295-4C99-9A8B-7DB3E9C2C70F',
#    'AgeGroup': 'M45-49',
#    'CountryRepresentingISONumeric': 862,
#    'BibNumber': 33054,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11165,
#    'FinishTime': 11165,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 26,
#    'FinishRankOverall': 26,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 26,
#    'RunRankOverall': 26,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Nixon Gutierrez', 'Gender': 'M'},
#    'Country': {'ISO2': 'VE'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:06:11',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:06:11',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'B8A83308-4A79-4AD7-AE72-B9A448E787CB',
#    'ContactId': '69A03E99-A5E5-4D49-9C96-343AE66AD86E',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30120,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11171,
#    'FinishTime': 11171,
#    'FinishRankGroup': 5,
#    'FinishRankGender': 27,
#    'FinishRankOverall': 27,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 5,
#    'RunRankGender': 27,
#    'RunRankOverall': 27,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Jeff Vinciguerra', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:06:21',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:06:21',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '85F79B2C-6F2C-4B61-A409-223F325409C8',
#    'ContactId': '6434054D-9BB5-46C2-AE6B-56DE826CE652',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 33058,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11181,
#    'FinishTime': 11181,
#    'FinishRankGroup': 6,
#    'FinishRankGender': 28,
#    'FinishRankOverall': 28,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 6,
#    'RunRankGender': 28,
#    'RunRankOverall': 28,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Matthew Katz', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:06:25',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:06:25',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'B2BA50BA-E54C-4001-BD8F-11B3650C7C5C',
#    'ContactId': '7FE2532C-6109-47AC-9D9A-B6EFEAF04F39',
#    'AgeGroup': 'F18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30002,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11185,
#    'FinishTime': 11185,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 1,
#    'FinishRankOverall': 29,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 1,
#    'RunRankOverall': 29,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Carson Davis', 'Gender': 'F'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:07:05',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:07:05',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'F6F90A92-0D85-4EBC-BCBC-7B0F89BDAA35',
#    'ContactId': 'CA394347-502A-47AA-9CAB-A36CCD48BACC',
#    'AgeGroup': 'M18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30061,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11225,
#    'FinishTime': 11225,
#    'FinishRankGroup': 5,
#    'FinishRankGender': 29,
#    'FinishRankOverall': 30,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 5,
#    'RunRankGender': 29,
#    'RunRankOverall': 30,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Willy Mcnamara', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:07:41',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:07:41',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'F754606A-CE91-4D48-B4AD-AD84E1D92BF4',
#    'ContactId': '294558F6-CBEF-4648-A037-67240EABA80B',
#    'AgeGroup': 'M40-44',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30119,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11261,
#    'FinishTime': 11261,
#    'FinishRankGroup': 3,
#    'FinishRankGender': 30,
#    'FinishRankOverall': 31,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 3,
#    'RunRankGender': 30,
#    'RunRankOverall': 31,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Jeffrey Suppinger', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:07:51',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:07:51',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'EA97141E-B1D9-4CB3-903A-67087F25F75B',
#    'ContactId': 'FECA1BFD-A878-454B-A0A5-4F19B22C94AD',
#    'AgeGroup': 'FElite',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 7,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11271,
#    'FinishTime': 11271,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 2,
#    'FinishRankOverall': 32,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 2,
#    'RunRankOverall': 32,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Leah Frazier Allen', 'Gender': 'F'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:11:16',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:11:16',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '4617BA20-74F9-4DDE-AE5C-A64EDB28F126',
#    'ContactId': '3A39C8FC-891B-4ADD-B7AC-E67D8248103E',
#    'AgeGroup': 'F18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30513,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11476,
#    'FinishTime': 11476,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 3,
#    'FinishRankOverall': 33,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 3,
#    'RunRankOverall': 33,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Emily Soppe', 'Gender': 'F'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:11:30',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:11:30',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '0C288C0F-EDAB-4695-86DD-AD0EC826D647',
#    'ContactId': '33FD871B-3FF4-4B1A-968D-1BAF36975416',
#    'AgeGroup': 'M18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 32300,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11490,
#    'FinishTime': 11490,
#    'FinishRankGroup': 6,
#    'FinishRankGender': 31,
#    'FinishRankOverall': 34,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 6,
#    'RunRankGender': 31,
#    'RunRankOverall': 34,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Anthony Jackson', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:11:59',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:11:59',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'DAD2A45E-3B0B-4547-A272-702B5879843C',
#    'ContactId': '91C3D69E-5C4E-41F2-A1D7-BECF7974B170',
#    'AgeGroup': 'M30-34',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30138,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11519,
#    'FinishTime': 11519,
#    'FinishRankGroup': 5,
#    'FinishRankGender': 32,
#    'FinishRankOverall': 35,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 5,
#    'RunRankGender': 32,
#    'RunRankOverall': 35,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Gregg Lamb', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:12:24',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:12:24',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '34FB09A1-146B-4033-8BC5-F0935D308586',
#    'ContactId': '7CCEE1FB-C033-4FF6-887C-DE0950714697',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 33055,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11544,
#    'FinishTime': 11544,
#    'FinishRankGroup': 7,
#    'FinishRankGender': 33,
#    'FinishRankOverall': 36,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 7,
#    'RunRankGender': 33,
#    'RunRankOverall': 36,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Caleb Chambers', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:12:40',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:12:40',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'E32D8A37-CC93-4589-93B5-AB75DD64A2EA',
#    'ContactId': '6905B85F-CA1F-47DC-87F1-12812C68A15B',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30046,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11560,
#    'FinishTime': 11560,
#    'FinishRankGroup': 6,
#    'FinishRankGender': 34,
#    'FinishRankOverall': 37,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 6,
#    'RunRankGender': 34,
#    'RunRankOverall': 37,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Josh Einspahr', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
# ...
#    'RunRankGroup': 7,
#    'RunRankGender': 35,
#    'RunRankOverall': 38,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Bryan Curtin', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:13:22',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:13:22',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'A8894C3E-4D43-40C0-9E6B-549025BA02F6',
#    'ContactId': '001EF862-F583-4195-947D-A6BC824E82BD',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30055,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11602,
#    'FinishTime': 11602,
#    'FinishRankGroup': 7,
#    'FinishRankGender': 36,
#    'FinishRankOverall': 39,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 7,
#    'RunRankGender': 36,
#    'RunRankOverall': 39,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Jason Schwab', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:13:58',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:13:58',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '670EABA6-4E58-4050-82D0-CDCF8E8234A3',
#    'ContactId': '4EB196DC-2934-4969-ACC9-0BC5D889DAEB',
#    'AgeGroup': 'M55-59',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30180,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11638,
#    'FinishTime': 11638,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 37,
#    'FinishRankOverall': 40,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 37,
#    'RunRankOverall': 40,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Steve Troxel', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:14:24',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:14:24',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '328D9DCB-752C-419E-905F-9ED2601EE473',
#    'ContactId': '8ED71D12-8BB8-409D-83F8-088DB94FDC27',
#    'AgeGroup': 'M30-34',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30145,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11664,
#    'FinishTime': 11664,
#    'FinishRankGroup': 6,
#    'FinishRankGender': 38,
#    'FinishRankOverall': 41,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 6,
#    'RunRankGender': 38,
#    'RunRankOverall': 41,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'David Burton', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:15:06',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:15:06',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '97951161-7128-4809-990E-3E2CA28DE688',
#    'ContactId': 'DF9C96F2-B346-4FA4-BE35-4AF06ACF1E9A',
#    'AgeGroup': 'M50-54',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 33195,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11706,
#    'FinishTime': 11706,
#    'FinishRankGroup': 2,
#    'FinishRankGender': 39,
#    'FinishRankOverall': 42,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 2,
#    'RunRankGender': 39,
#    'RunRankOverall': 42,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Scott Slavens', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:15:27',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:15:27',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'B55F5298-716B-4434-989E-9CCC96B0CCE1',
#    'ContactId': '12E4D6E5-5C15-4073-B101-71434194E006',
#    'AgeGroup': 'F35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30124,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11727,
#    'FinishTime': 11727,
#    'FinishRankGroup': 1,
#    'FinishRankGender': 4,
#    'FinishRankOverall': 43,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 1,
#    'RunRankGender': 4,
#    'RunRankOverall': 43,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Allison Koch', 'Gender': 'F'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:15:38',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:15:38',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '0D489659-04C3-404A-B3C1-D8F0F57A2CA3',
#    'ContactId': '2F9A5DDC-826C-4958-8B38-02BCFEB72763',
#    'AgeGroup': 'M40-44',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30210,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11738,
#    'FinishTime': 11738,
#    'FinishRankGroup': 4,
#    'FinishRankGender': 40,
#    'FinishRankOverall': 44,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 4,
#    'RunRankGender': 40,
#    'RunRankOverall': 44,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Richard Sanzone', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:15:42',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:15:42',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '63027DB5-BFC2-41C5-8AF2-840675FB0DFD',
#    'ContactId': 'AAFD97E4-C4FF-4F34-9F58-C889D99FDA26',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30149,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11742,
#    'FinishTime': 11742,
#    'FinishRankGroup': 8,
#    'FinishRankGender': 41,
#    'FinishRankOverall': 45,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 8,
#    'RunRankGender': 41,
#    'RunRankOverall': 45,
#    'SyncDate': '2021-01-06T05:41:51.290Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Alan Arpon', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:15:49',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:15:49',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'EF8AB425-046E-471E-A294-00988627B615',
#    'ContactId': 'DC4CB2A0-C48B-486C-A5FD-A849C6BFA63A',
#    'AgeGroup': 'M18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 33203,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11749,
#    'FinishTime': 11749,
#    'FinishRankGroup': 8,
#    'FinishRankGender': 42,
#    'FinishRankOverall': 46,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 8,
#    'RunRankGender': 42,
#    'RunRankOverall': 46,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Remington Ponce-Pore', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:15:54',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:15:54',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '61EB33B0-A3B3-49F2-8DC6-5081F898A897',
#    'ContactId': '7B21D6C7-7549-4697-9694-AC756634060C',
#    'AgeGroup': 'F18-24',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30259,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11754,
#    'FinishTime': 11754,
#    'FinishRankGroup': 3,
#    'FinishRankGender': 5,
#    'FinishRankOverall': 47,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 3,
#    'RunRankGender': 5,
#    'RunRankOverall': 47,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Tara Austin', 'Gender': 'F'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:15:57',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:15:57',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'C024FA9F-45B1-4705-B247-3DE12AD3425A',
#    'ContactId': '0E0F01D4-6608-4969-9EB1-00A407F36BFE',
#    'AgeGroup': 'M35-39',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30179,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11757,
#    'FinishTime': 11757,
#    'FinishRankGroup': 9,
#    'FinishRankGender': 43,
#    'FinishRankOverall': 48,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 9,
#    'RunRankGender': 43,
#    'RunRankOverall': 48,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'Cyrille Tiberghien', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:17:04',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:17:04',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': 'F800F132-1CD1-4BD5-9B15-5524D893DC1A',
#    'ContactId': '8C313FCC-FC86-4B79-82C2-7CF28DEC36F3',
#    'AgeGroup': 'M40-44',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 30097,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11824,
#    'FinishTime': 11824,
#    'FinishRankGroup': 5,
#    'FinishRankGender': 44,
#    'FinishRankOverall': 49,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 5,
#    'RunRankGender': 44,
#    'RunRankOverall': 49,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'David Long', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None},
#   {'RunTimeConverted': '3:18:39',
#    'SwimTimeConverted': '00:00:00',
#    'BikeTimeConverted': '00:00:00',
#    'FinishTimeConverted': '3:18:39',
#    'Transition1TimeConverted': '00:00:00',
#    'Transition2TimeConverted': '00:00:00',
#    'CountryISO2': 'US',
#    'SubeventName': "2019 Rock 'n' Roll Nashville Marathon",
#    'ResultId': '2D03A0AF-76A1-442A-8EC9-5EA454DD67DD',
#    'ContactId': 'C3C917FE-B307-4EA5-AE6F-EC82B209AA64',
#    'AgeGroup': 'M25-29',
#    'CountryRepresentingISONumeric': 840,
#    'BibNumber': 31210,
#    'EventStatus': 'Finish',
#    'SwimTime': 0,
#    'Transition1Time': 0,
#    'BikeTime': 0,
#    'Transition2Time': 0,
#    'RunTime': 11919,
#    'FinishTime': 11919,
#    'FinishRankGroup': 8,
#    'FinishRankGender': 45,
#    'FinishRankOverall': 50,
#    'SwimRankGroup': 99999,
#    'SwimRankGender': 99999,
#    'SwimRankOverall': 99999,
#    'BikeRankGroup': 99999,
#    'BikeRankGender': 99999,
#    'BikeRankOverall': 99999,
#    'RunRankGroup': 8,
#    'RunRankGender': 45,
#    'RunRankOverall': 50,
#    'SyncDate': '2019-08-15T15:35:53.620Z',
#    'SubEventId': '622BBEE3-D94F-E811-941E-005056951BF1',
#    'RankPoints': None,
#    'Contact': {'FullName': 'David Quiroga', 'Gender': 'M'},
#    'Country': {'ISO2': 'US'},
#    'Subevent': {'SubEvent': "2019 Rock 'n' Roll Nashville Marathon"},
#    'Badge_Result': None}]}

# %% [markdown]
# ### 2019 results

# %%
# Start with an empty list
results_2019 = []

# Loop through from pages 1 to 57
for page_num in range(1, 58):
    # Build the URL and download the results
    url = 'https://api.competitor.com/public/result/subevent/622BBEE3-D94F-E811-941E-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip=' + str((page_num-1)*50)
    #print("Downloading", url)
    response = requests.get(url, headers = {'WTC_PRIV_KEY': '90da38d91a0648f89823e375a43b2dc8'})
    data = response.json()
    results_2019 = results_2019 + data['data']


print("We have", len(results_2019), "total results")
# Out:
# We have 2811 total results

# %%
resp_19 = pd.DataFrame(results_2019)
resp_19.shape
# Out:
# (2811, 39)

# %%
resp_19_split = pd.concat([resp_19.drop(['Contact'], axis=1), resp_19['Contact'].apply(pd.Series)], axis=1)
resp_19_split.head(3)
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          1:37:54          00:00:00          00:00:00             1:37:54
# 1          2:34:59          00:00:00          00:00:00             2:34:59
# 2          2:35:24          00:00:00          00:00:00             2:35:24
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2019 Rock 'n' Roll Nashville Marathon
# 1  2019 Rock 'n' Roll Nashville Marathon
# 2  2019 Rock 'n' Roll Nashville Marathon
#
#                                ResultId                             ContactId  \
# 0  BAD64F55-2468-4852-B2D7-79645CC406CF  EB221D69-153D-4604-96E0-274EB04F452C
# 1  BA893A3C-B2BB-4C83-B372-AF68521F7FB6  BED376E7-A066-43C9-A759-4C476A939CFA
# 2  B67E182D-62C5-493F-BEE8-83363643BE44  936B5582-6102-42FC-8F8A-559D44484658
#
#    ... RunRankGender  RunRankOverall                  SyncDate  \
# 0  ...             1               1  2019-08-15T15:35:53.620Z
# 1  ...             2               2  2019-08-15T15:35:53.620Z
# 2  ...             3               3  2020-03-17T16:30:36.613Z
#
#                              SubEventId  RankPoints         Country  \
# 0  622BBEE3-D94F-E811-941E-005056951BF1        None  {'ISO2': 'US'}
# 1  622BBEE3-D94F-E811-941E-005056951BF1        None  {'ISO2': 'US'}
# 2  622BBEE3-D94F-E811-941E-005056951BF1        None  {'ISO2': 'US'}
#
#                                             Subevent  Badge_Result  \
# 0  {'SubEvent': '2019 Rock 'n' Roll Nashville Mar...          None
# 1  {'SubEvent': '2019 Rock 'n' Roll Nashville Mar...          None
# 2  {'SubEvent': '2019 Rock 'n' Roll Nashville Mar...          None
#
#          FullName  Gender
# 0  Travis Peruski       M
# 1  Scott Wietecha       M
# 2   Jordan Wilson       M
#
# [3 rows x 40 columns]

# %%
resp_19_split = pd.concat([resp_19_split.drop(['Country'], axis=1), resp_19_split['Country'].apply(pd.Series)], axis=1)

# %%
resp_19_split = pd.concat([resp_19_split.drop(['Subevent'], axis=1), resp_19_split['Subevent'].apply(pd.Series)], axis=1)

# %% [markdown]
# ### 2018 results

# %%
# Start with an empty list
results_2018 = []

# Loop through from pages 1 to 43
for page_num in range(1, 44):
    # Build the URL and download the results
    url = 'https://api.competitor.com/public/result/subevent/DEDEEE82-E676-E711-9418-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip=' + str((page_num-1)*50)
    #print("Downloading", url)
    response = requests.get(url, headers = {'WTC_PRIV_KEY': '90da38d91a0648f89823e375a43b2dc8'})
    data = response.json()
    results_2018 = results_2018 + data['data']


print("We have", len(results_2018), "total results")
# Out:
# We have 2115 total results

# %%
resp_18 = pd.DataFrame(results_2018)
resp_18.shape
# Out:
# (2115, 39)

# %%
resp_18_split = pd.concat([resp_18.drop(['Contact'], axis=1), resp_18['Contact'].apply(pd.Series)], axis=1)
resp_18_split.head(3)
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:28:16          00:00:00          00:00:00             2:28:16
# 1          2:29:52          00:00:00          00:00:00             2:29:52
# 2          2:38:59          00:00:00          00:00:00             2:38:59
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2018 Rock 'n' Roll Nashville Marathon
# 1  2018 Rock 'n' Roll Nashville Marathon
# 2  2018 Rock 'n' Roll Nashville Marathon
#
#                                ResultId                             ContactId  \
# 0  DADF30D3-22B2-462B-A45B-1D7666205CC2  BED376E7-A066-43C9-A759-4C476A939CFA
# 1  7C438977-D240-4673-AB86-B78D2A236A04  313A73F2-42E8-409A-8277-22EF75126C9A
# 2  48893DFE-3771-4525-966D-FD6770FCD546  5831AFE3-152E-4F06-A315-049E21256DB5
#
#    ... RunRankGender  RunRankOverall                  SyncDate  \
# 0  ...             1               1  2019-08-15T15:35:53.620Z
# 1  ...             2               2  2019-08-15T15:35:53.620Z
# 2  ...             3               3  2019-08-15T15:35:53.620Z
#
#                              SubEventId  RankPoints         Country  \
# 0  DEDEEE82-E676-E711-9418-005056951BF1        None  {'ISO2': 'US'}
# 1  DEDEEE82-E676-E711-9418-005056951BF1        None  {'ISO2': 'US'}
# 2  DEDEEE82-E676-E711-9418-005056951BF1        None  {'ISO2': 'US'}
#
#                                             Subevent  Badge_Result  \
# 0  {'SubEvent': '2018 Rock 'n' Roll Nashville Mar...          None
# 1  {'SubEvent': '2018 Rock 'n' Roll Nashville Mar...          None
# 2  {'SubEvent': '2018 Rock 'n' Roll Nashville Mar...          None
#
#          FullName  Gender
# 0  Scott Wietecha       M
# 1    Garang Madut       M
# 2      Kevin Fink       M
#
# [3 rows x 40 columns]

# %%
resp_18_split = pd.concat([resp_18_split.drop(['Country'], axis=1), resp_18_split['Country'].apply(pd.Series)], axis=1)

# %%
resp_18_split = pd.concat([resp_18_split.drop(['Subevent'], axis=1), resp_18_split['Subevent'].apply(pd.Series)], axis=1)

# %% [markdown]
# ### 2017 Results

# %%
# Start with an empty list
results_2017 = []

# Loop through from pages 1 to 74
for page_num in range(1, 75):
    # Build the URL and download the results
    url = 'https://api.competitor.com/public/result/subevent/9D1CE788-E676-E711-9418-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip=' + str((page_num-1)*50)
    #print("Downloading", url)
    response = requests.get(url, headers = {'WTC_PRIV_KEY': '90da38d91a0648f89823e375a43b2dc8'})
    data = response.json()
    results_2017 = results_2017 + data['data']


print("We have", len(results_2017), "total results")
# Out:
# We have 3651 total results

# %%
resp_17 = pd.DataFrame(results_2017)
resp_17.shape
# Out:
# (3651, 39)

# %%
resp_17_split = pd.concat([resp_17.drop(['Contact'], axis=1), resp_17['Contact'].apply(pd.Series)], axis=1)
resp_17_split.head(3)
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:40:25          00:00:00          00:00:00             2:40:25
# 1          2:56:28          00:00:00          00:00:00             2:56:28
# 2          3:00:55          00:00:00          00:00:00             3:00:55
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2017 Rock 'n' Roll Nashville Marathon
# 1  2017 Rock 'n' Roll Nashville Marathon
# 2  2017 Rock 'n' Roll Nashville Marathon
#
#                                ResultId                             ContactId  \
# 0  3E2251A4-B267-405B-AFCA-40062AF11F3C  BED376E7-A066-43C9-A759-4C476A939CFA
# 1  DC2458F7-2667-4465-A72E-3775C85331E3  2798FABB-57BE-4E0A-A232-BCB7F2848407
# 2  73A2A4A1-71A1-4A3F-ACA9-3538B3FD62A4  F133892E-0A21-4B04-8F45-57F194D9AF9B
#
#    ... RunRankGender  RunRankOverall                  SyncDate  \
# 0  ...             1               1  2019-08-15T15:35:53.620Z
# 1  ...             2               2  2019-08-15T15:35:53.620Z
# 2  ...             3               3  2019-08-15T15:35:53.620Z
#
#                              SubEventId  RankPoints         Country  \
# 0  9D1CE788-E676-E711-9418-005056951BF1        None  {'ISO2': 'US'}
# 1  9D1CE788-E676-E711-9418-005056951BF1        None  {'ISO2': 'US'}
# 2  9D1CE788-E676-E711-9418-005056951BF1        None  {'ISO2': 'US'}
#
#                                             Subevent  Badge_Result  \
# 0  {'SubEvent': '2017 Rock 'n' Roll Nashville Mar...          None
# 1  {'SubEvent': '2017 Rock 'n' Roll Nashville Mar...          None
# 2  {'SubEvent': '2017 Rock 'n' Roll Nashville Mar...          None
#
#          FullName  Gender
# 0  Scott Wietecha       M
# 1    Ryan Regnier       M
# 2  Daniel Everett       M
#
# [3 rows x 40 columns]

# %%
resp_17_split = pd.concat([resp_17_split.drop(['Country'], axis=1), resp_17_split['Country'].apply(pd.Series)], axis=1)

# %%
resp_17_split = pd.concat([resp_17_split.drop(['Subevent'], axis=1), resp_17_split['Subevent'].apply(pd.Series)], axis=1)

# %%
#marathon_results_2017.to_csv('./data/marathon_results_2017.csv', index=False)

# %%
resp_19_split.to_csv('../data/maraton_results_2019.csv', index=False)

# %%
resp_18_split.to_csv('../data/maraton_results_2018.csv', index=False)

# %%
resp_17_split.to_csv('../data/maraton_results_2017.csv', index=False)
